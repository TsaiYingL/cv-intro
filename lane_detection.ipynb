# %%
import lane_detection
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.cvtColor(cv2.imread("bwsi_pool.png"), cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 300, 350, apertureSize=5)  # Detect edges
lines = cv2.HoughLinesP(
                edges,
                1,
                np.pi/180,
                100,
                minLineLength=500,
                maxLineGap=30,
        ) # detect lines

for line in lines:
    x1, y1, x2, y2 = line[0]
    cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

print(lines)
print(len(lines))
plt.imshow(img)
# Out:
# [[[2969 1080 3697 1169]]
#
#  [[2536 1079 3367 1241]]
#
#  [[2635 1038 3384 1130]]
#
#  [[3198 1206 3761 1315]]
#
#  [[   3 1860  734 1455]]
#
#  [[  86 1815  660 1497]]
#
#  [[3306 1226 3814 1325]]
#
#  [[ 146 1780  719 1462]]
#
#  [[2548 1082 3135 1196]]]
# 9

# %%
lines = lane_detection.detect_lines("bwsi_pool.png", 300, 350, 5, 500, 30)
print(lines)
# Out:
# [[[2319 1036 3007 1170]]
#
#  [[2944 1076 3819 1184]]
#
#  [[1069 2023 1468 1359]]
#
#  [[2536 1079 3215 1211]]
#
#  [[   2 1860  716 1464]]
#
#  [[3203 1206 3762 1315]]
#
#  [[1141 1901 1466 1360]]
#
#  [[1007 2131 1313 1621]]
#
#  [[3185 1204 3743 1312]]
#
#  [[2220 1019 2932 1157]]
#
#  [[   5 1860  741 1452]]
#
#  [[   1 1860  616 1519]]]

# %%
lane_detection.draw_lines(img, lines)
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 lane_detection.draw_lines(img, lines)
#       2 plt.imshow(img)
#
# File ~/cv-intro/lane_detection.py:23, in draw_lines(img, lines, color)
#      22 def draw_lines(img:str, lines:list, color:tuple = (0, 255, 0)):
# ---> 23     image = cv2.imread(img)
#      25     for line in lines:
#      26         print(line)
#
# TypeError: Can't convert object to 'str' for 'filename'
